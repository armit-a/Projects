# %% [markdown]
# The link of the google colab notebook is https://colab.research.google.com/drive/1NsFut52doog5P4HtE97RYH72ZrpEozlR?usp=sharing

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#I'll be doing EDA(exploratory data analysis ) with a dataset called "Movies".
#Here's the link for that datastet. URL="https://www.kaggle.com/datasets/ashvanths/toprated-tmdb-movies"

# %%
df=pd.read_csv('Movies.csv')
df
# Out:
#       Unnamed: 0      id  adult                                title  \
# 0              0     278  False             The Shawshank Redemption
# 1              1   19404  False          Dilwale Dulhania Le Jayenge
# 2              2     238  False                        The Godfather
# 3              3     424  False                     Schindler's List
# 4              4     240  False                The Godfather Part II
# ...          ...     ...    ...                                  ...
# 5884        5884  329263  False                 Suck Me Shakespeer 2
# 5885        5885  109451  False  Cloudy with a Chance of Meatballs 2
# 5886        5886    4141  False                         Shoot 'Em Up
# 5887        5887   11584  False                              Roxanne
# 5888        5888  531219  False             Roald Dahl's The Witches
#
#      original_language                                           overview  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5889 entries, 0 to 5888
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5889 non-null   int64
#  1   id                 5889 non-null   int64
#  2   adult              5889 non-null   bool
#  3   title              5889 non-null   object
#  4   original_language  5889 non-null   object
#  5   overview           5888 non-null   object
#  6   title.1            5889 non-null   object
#  7   popularity         5889 non-null   float64
#  8   release_date       5889 non-null   object
#  9   vote_average       5889 non-null   float64
#  10  vote_count         5888 non-null   float64
# dtypes: bool(1), float64(3), int64(2), object(5)
# memory usage: 466.0+ KB

# %%
#So in our dataset there are 5889 rows and 11 columns. But out of 11 columns unnamed: 0 and id columns aren't useful. So let's drop them
df.drop(['Unnamed: 0', 'id','title'], axis=1)
# Out:
#       adult original_language  \
# 0     False                en
# 1     False                hi
# 2     False                en
# 3     False                en
# 4     False                en
# ...     ...               ...
# 5884  False                de
# 5885  False                en
# 5886  False                en
# 5887  False                en
# 5888  False                en
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 5884  Mr. Müller is not satisfied with his new work ...
# 5885  After the disastrous food storm in the first f...
# 5886  A man named Mr. Smith delivers a woman's baby ...
# ...

# %%
#Waah! It's clear now
df['release_date'] = df['release_date'].astype('int64')
sns.distplot(df['release_date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Fact1. Maximum movies of the dataset are released during the years(approxmately) 2010 to 2020

# %%
df['original_language'].value_counts()
# Out:
# en    4287
# fr     408
# ja     258
# it     252
# es     152
# de      89
# ko      74
# cn      48
# zh      47
# hi      39
# ru      38
# pt      34
# sv      32
# da      28
# no      14
# pl      12
# nl      11
# tr      10
# th       7
# fa       7
# hu       6
# id       5
# el       3
# ar       3
# cs       3
# is       3
# sr       2
# te       2
# ro       2
# fi       2
# la       1
# nb       1
# eu       1
# uk       1
# af       1
# bn       1
# ml       1
# sh       1
# bs       1
# et       1
# he       1
# Name: original_language, dtype: int64

# %% [markdown]
# Fact2. Maximum number of movies have their original language as English. 2nd highest of movies are of french and 3rd is japaneese.

# %%
df[['title.1','vote_count']].max()#This shows the movie which has got max voting.
# Out:
# title.1       tick, tick... BOOM!
# vote_count                32055.0
# dtype: object

# %% [markdown]
# Fact3. The movie "tick,tick... BOOM!" has got max number of votes

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# id                   0
# adult                0
# title                0
# original_language    0
# overview             1
# title.1              0
# popularity           0
# release_date         0
# vote_average         0
# vote_count           1
# dtype: int64

# %%
df[['original_language','vote_count']].max()
# Out:
# original_language         zh
# vote_count           32055.0
# dtype: object

# %% [markdown]
# Fact4. The highest voted movie is a chinese movie.

# %%
enm =df.loc[(df.original_language == 'en') & (df.vote_count> 30000)]
enm
# Out:
#     Unnamed: 0     id  adult      title original_language  \
# 57          57  27205  False  Inception                en
#
#                                              overview    title.1  popularity  \
# 57  Cobb, a skilled thief who commits corporate es...  Inception      138.28
#
#     release_date  vote_average  vote_count
# 57      20100715           8.4     32055.0

# %% [markdown]
# Fact5. In english language one movie has got votes greater than 30k and the movie is 'Inception'.

# %%
df[['release_date','title.1','original_language']].min()
# Out:
# release_date         19020417
# title.1                #Alive
# original_language          af
# dtype: object

# %% [markdown]
# Fact6. According to my dataset the first movie released in 1902.04.17 ,named "#Alive", which is an afrikaan movie.

# %%
df[['vote_average','title.1','original_language']].min()
# Out:
# vote_average            6.0
# title.1              #Alive
# original_language        af
# dtype: object

# %% [markdown]
# Fact7. According to my dataset the afrikaan movie "#Alive " has the lowest rating of 6.

# %%
df[['vote_average','title.1','original_language']].max()
# Out:
# vote_average                         8.7
# title.1              tick, tick... BOOM!
# original_language                     zh
# dtype: object

# %%
df[['vote_average','title.1','original_language']].max()
# Out:
# vote_average                         8.7
# title.1              tick, tick... BOOM!
# original_language                     zh
# dtype: object

# %% [markdown]
# Fact8. According to my dataset the chinese movie "tick, tick... BOOM!" has the highest rating of 8.7

# %%
df.groupby(['adult']).size()
# Out:
# adult
# False    5889
# dtype: int64

# %% [markdown]
# Fact9. All the movies contained in the dataset are non-adult movies.

# %%
df[['popularity','title.1','original_language']].max()
# Out:
# popularity                     16755.428
# title.1              tick, tick... BOOM!
# original_language                     zh
# dtype: object

# %%
df[['popularity','title.1','original_language']].min()
# Out:
# popularity              0.6
# title.1              #Alive
# original_language        af
# dtype: object

# %% [markdown]
# Fact10. According to my dataset among all the movies released between 1902.04.17 to 2022.08.05 most popular movie is "tick, tick... BOOM!"and least popular is "#Alive".

# %%
am=df.loc[(df.original_language == 'en') & (df.popularity > 10000)]
am
# Out:
#      Unnamed: 0      id  adult title original_language  \
# 174         174  766507  False  Prey                en
#
#                                               overview title.1  popularity  \
# 174  When danger threatens her camp, the fierce and...    Prey   16755.428
#
#      release_date  vote_average  vote_count
# 174      20220802           8.2      2280.0

# %% [markdown]
# Fact11. There is only 1 movie in english language which has popuarity more than 10k, named "Prey".

# %%
am2=df.loc[(df.original_language == 'en') & (df.vote_average ==8.7)]
am2
# Out:
#    Unnamed: 0   id  adult                     title original_language  \
# 0           0  278  False  The Shawshank Redemption                en
# 2           2  238  False             The Godfather                en
#
#                                             overview  \
# 0  Framed in the 1940s for the double murder of h...
# 2  Spanning the years 1945 to 1955, a chronicle o...
#
#                     title.1  popularity  release_date  vote_average  \
# 0  The Shawshank Redemption      86.715      19940923           8.7
# 2             The Godfather     121.661      19720314           8.7
#
#    vote_count
# 0     21988.0
# 2     16371.0

# %% [markdown]
# Fact12. In english language there are 2 movies which has got 8.7 ratings (highest in english language). Name of those are "The Shawsank Redemption", "The Godfather".
